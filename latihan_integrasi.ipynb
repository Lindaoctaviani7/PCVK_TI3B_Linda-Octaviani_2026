# %% [markdown]
# <a href="https://colab.research.google.com/github/Lindaoctaviani7/PCVK_TI3B_Linda-Octaviani_2026/blob/main/latihan_integrasi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# JOBSHEET WEEK 1
# NAMA: LINDA OCTAVIANI
# NIM: 244107020002
# KELAS: TI3B

# %% [markdown]
# STEP 1

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# STEP 2

# %%
# membuat list untuk menyimpan url dari beberapa image
urls = [
    "https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
    "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
]
#baca dan tampilkan image
#loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                            #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)   #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)    #convert color to RGB
  final_frame = cv.hconcat((image, image_2))        #concatenate image
  cv2_imshow(final_frame)                           #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# STEP 3

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ", tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %% [markdown]
# STEP 4

# %%
image_gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
image_gray_display = cv.cvtColor(image_gray, cv.COLOR_GRAY2BGR)
image_1 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for x in range(lebar):
  image_1[tinggi//2, x] = [255,255,255]

final_frame = cv.hconcat((image_gray_display, image_1))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# JAWABAN PERTANYAAN PRAKTIKUM D2
#
# 1. Google Colab digunakan karena berbasis cloud, sehingga pengguna tidak perlu menginstal Python dan library secara lokal. Colab juga menyediakan berbagai berbagai library seperti OpenCV, NumPy, Matplotlib,TensorFlow, dan PyTorch, serta terhubung dengan Google Drive dan GitHub untuk memudahkan penyimpanan dan kolaborasi
#
# 2. - cv2 (OpenCV) digunakan untuk membaca gambar, resize gambar, konversi warna, dan pengolahan citra
# - NumPy digunakan untuk array multidimensi, manipulasi pixel, dan operasi mattriks
# - matplotlib.pyplot digunakan untuk menampilkan gambar dan plotting image
# - skimage.io digunakan gambar dari url
# - cv2_imshow digunakan untuk menampilkn gambar OpenCV pada Google Colab
# 3. Kegunaannya adalah memperkecil ukuran gambar menjadi 50% dari ukuran aslinya, sehingga proses pengolahan gambar lebih cepat dan penggunaan memori lebih kecil. Jika tidak dilakukan maka gambar tetap berukuran asli, sehingga membutuhkan lebih banyak memori dan waktu pemrosesan lebih lama.
# 4. kode [255,255,255] merupakan warna putih pada citra RGB
# 5. resolusi merupakan jumlah pixel yang terdapat pada suatu gambar. semakin tinggi resolusi maka semakin banyak pixel yang dimiliki sehingga detail gambar menjadi lebih baik. sebaliknya, resolusi rendah memiliki jumlah pixel lebih sedikit sehingga gambar terlihat kurang tajam atau pecah ketika diperbesar.

# %% [markdown]
# TUGAS PRAKTIKUM D2

# %% [markdown]
# GARIS VERTIKAL

# %%
image_gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
image_gray_display = cv.cvtColor(image_gray, cv.COLOR_GRAY2BGR)
image_1 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis vertikal ditengah image
for y in range(tinggi):
  image_1[y, lebar//2] = [255,255,255]

final_frame = cv.hconcat((image_gray_display, image_1))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# GARIS MENYILANG

# %%
image_gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
image_gray_display = cv.cvtColor(image_gray, cv.COLOR_GRAY2BGR)
image_1 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

cv.line(image_1, (0, 0), (lebar - 1, tinggi - 1),
        (255,255,255), 2)
cv.line(image_1, (lebar - 1, 0), (0, tinggi - 1),
        (255,255,255), 2)
hasil = cv.hconcat([image_gray_display, image_1])

cv2_imshow(hasil)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# GARIS HORIZONTAL PUTIH DITENGAH

# %%
image_gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
image_gray_display = cv.cvtColor(image_gray, cv.COLOR_GRAY2BGR)
image_1 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# mengambil ukuran gambar
tinggi, lebar = image_1.shape[:2]

# membuat garis horizontal kecil di tengah image
panjang_garis = 80  # ukuran panjang garis

x_awal = (lebar//2) - (panjang_garis//2)
x_akhir = (lebar//2) + (panjang_garis//2)

for x in range(x_awal, x_akhir):
    image_1[tinggi//2, x] = [255,255,255]

final_frame = cv.hconcat((image_gray_display, image_1))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# MEMBUAT KOTAK KUMPULAN PIXEL

# %%
image_gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
image_gray_display = cv.cvtColor(image_gray, cv.COLOR_GRAY2BGR)
image_1 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Mengambil ukuran gambar
tinggi, lebar = image_1.shape[:2]

# Ukuran kotak kecil di tengah
ukuran_kotak = 80   # panjang sisi kotak pixel

# Menentukan koordinat kotak
x_awal = (lebar//2) - (ukuran_kotak//2)
x_akhir = (lebar//2) + (ukuran_kotak//2)

y_awal = (tinggi//2) - (ukuran_kotak//2)
y_akhir = (tinggi//2) + (ukuran_kotak//2)

# Mengubah kumpulan pixel menjadi warna putih
for y in range(y_awal, y_akhir):
    for x in range(x_awal, x_akhir):
        image_1[y, x] = [255, 255, 255]

final_frame = cv.hconcat((image_gray_display, image_1))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>
